# %%
import csv
import random

# Generate fake data for places profile with unique place IDs
def generate_data(num_samples):
    # Define possible values for each field
    places_names = ['Costa Coffee - Citystars Mall, Cairo','Starbucks - Nile City Towers, Cairo','Cilantro - Maadi, Cairo',
                'Beano\'s Cafe - Maadi, Cairo','Coffee Beanery - Cairo Festival City Mall, Cairo','Caribou Coffee - Downtown Mall, Cairo',
                'The Coffee House - Maadi, Cairo','Trianon Cafe - Maadi, Cairo','Cinnabon Cafe - Citystars Mall, Cairo',
                'Second Cup - Mall of Egypt, Giza','Tim Hortons - Citystars Mall, Cairo','Coffee Lounge - Zamalek, Cairo',
                'Mugg & Bean - Zamalek, Cairo','Bon Appetit - Heliopolis, Cairo','Caffè Greco - Downtown, Cairo','Green & Beans - Maadi, Cairo',
                'La Poire Cafe - Nasr City, Cairo','Le Chantilly - Heliopolis, Cairo','Panorama Cafe - Downtown, Cairo',
                'Roasting House - New Cairo, Cairo','Yalla Bina - Mohandeseen, Cairo','Coffee Republic - Maadi, Cairo',
                'Cafe Supreme - Maadi, Cairo','Caffeine - Dokki, Cairo','T-Spot - Nasr City, Cairo','Felfela - Downtown, Cairo',
                'Java Java - Heliopolis, Cairo','Espresso Lab - Maadi, Cairo','Gourmandise - Zamalek, Cairo','The Kitchenette - New Cairo, Cairo',
                'The Corner - Mohandeseen, Cairo','The GrEEK Campus - Tahrir Square, Cairo','Caffè Nero - Cairo Festival City Mall, Cairo',
                'Dunkin\' Donuts - Multiple locations in Cairo','Paul Bakery & Cafe - Nile City Towers, Cairo','Cafe Supremo - New Cairo, Cairo',
                'Sufi - Zamalek, Cairo','Brioche Doree - Cairo Festival City Mall, Cairo','Caffe Greco - Heliopolis, Cairo','Cafe Tabasco - Maadi, Cairo',
                'Cafe Supreme - Zamalek, Cairo','Delice - Heliopolis, Cairo','Pascucci - Mall of Egypt, Giza','CinnZeo Bakery Cafe - Mall of Egypt, Giza',
                'El Beit - Zamalek, Cairo','Cafeina - New Cairo, Cairo','Tche Tche - Zamalek, Cairo','Divino Cafe & Restaurant - Maadi, Cairo',
                'Gardenia Cafe - Maadi, Cairo','Mince - New Cairo, Cairo','Filfila - Downtown, Cairo','Cafe Greco - Zamalek, Cairo',
                'Costa Coffee - Multiple locations in Cairo','Grand Cafe - Zamalek, Cairo','Tintawi - Maadi, Cairo','TBS - Heliopolis, Cairo',
                'Caffe Greco - Dokki, Cairo','The Bakery - Heliopolis, Cairo','La Maison Blanche - Heliopolis, Cairo','The Greek - Heliopolis, Cairo',
                'The GrEEK Campus - New Cairo, Cairo','Eish & Malh - Zamalek, Cairo',"Pub 28, Cairo","Le Deck, Alexandria","Cairo Jazz Club, Cairo",
                "The Tap Maadi, Cairo","Harry's Pub, Cairo","Cairo Capital Club, Cairo","Odeon Palace, Alexandria","The Tap West, Cairo",
                "The Lemon Tree & Co., Cairo","The Cellar, Cairo","The Tipsy Teapot, Cairo","L'Oasis, Cairo","Roof Bar, Cairo","The Tap East, Cairo",
                "The Smokery Beach, Alexandria","The Irish House, Cairo","Buddha-Bar, Cairo","Nozha Beach Club, Alexandria","Club 35, Cairo",
                "Sky Roof Bar & Lounge, Alexandria","Tipplers Bar, Cairo","Bus Stop, Cairo","Left Bank, Cairo","Pane Vino, Alexandria",
                "El Rowad, Cairo","Belal & Barzilai, Alexandria","Tamarai, Cairo","Taht El Saytara, Cairo","Rooftop Lounge & Bar, Alexandria",
                "La Bodega, Cairo","Little Buddha, Sharm El Sheikh","Grand Cafe, Cairo","La Bodega, Alexandria","The Backyard, Cairo",
                "The Terrace, Cairo","Soho Square, Sharm El Sheikh","Sabai Sabai, Cairo","Koshari Abou Tarek, Cairo","Fat Harry's, Cairo",
                "Loft21, Cairo","Indigo, Cairo","Sand Bar, Hurghada","Hard Rock Cafe, Cairo","Mojo Lounge & Grill, Cairo","Teatro, Cairo",
                "Buddha-Bar Beach, Sahel","Wunder Garten, Alexandria","The Bar, Cairo","Pegasus Lounge Bar, Alexandria","Terrace Cafe & Bar, Cairo",
                "The Royal Crown, Alexandria","I Bistro Bar, Cairo","The Lodge, Cairo","The Bistro, Cairo","The Tap Maadi Street 9, Cairo",
                "Deck 35, Alexandria","6IX Degrees, Cairo","Bamboo Beach, Hurghada","Les Amis, Cairo","Gouna Yacht Club, Hurghada",
                "O2 Lounge, Sharm El Sheikh","9 Lounge, Cairo","24K, Cairo","Enab Beirut, Cairo","Indigo Beach Club, Hurghada","Livingstone, Cairo",
                "Sky Bar, Hurghada","Cap d'Or, Alexandria","Tamara Lebanese Bistro, Cairo","Seagull Beach Bar, Hurghada""Harry's Pub, Alexandria",
                "Left Bank, Alexandria","Amici Bar & Grill, Cairo","Rio Nightclub, Sharm El Sheikh","The Lodge Bar, Alexandria",
                "The Tap Maadi Street 231, Cairo","La Plage, Alexandria","The Greek Campus, Cairo","El Horreya, Alexandria","Buddha-Bar, Sahel",
                "The Tap Downtown, Cairo","El Fishawy, Cairo","The Smokery, Cairo","Al-Azhar Park","Cairo International Park","Family Park in Maadi",
                "Al Horreya Park","Giza Zoo","Aswan Botanical Garden","Tivoli Dome","Gezira Club","Dream Park","Alexandria Zoo","Wadi Degla Protectorate",
                "Al Montazah Park","Fustat Park","Magic Land","Borg El Arab Stadium","City Stars Park","Ras Mohamed National Park","Al Andalus Park",
                "Ghibli Raceway","The Marina El Alamein","Tahrir Square","Siwa Oasis","Taziry Ecolodge Siwa","Al-Fayoum Oasis","Al-Galala Mountain",
                "Mersa Matrouh Beach","Al-Orman Garden","Oyoun Mousa","Cairo Festival City","Al Madina Park","Al-Masah Hotel and Spa","Pharos Island",
                "Zahran Park","Alex Park","Gabal Albaqar Mountain","Madinaty City","Al Rehab City","Al-Mashaya Reserve","Nubian Village",
                "The Great Sand Sea","El Fayoum Oasis","Al Khazan Park","Abu Simbel Temple","El Gouna","Serapium Forest","Al Mamoura Beach",
                "Ras El Bar","El Nabatat Island","Wadi Al-Natrun","Al Kholafaa Al Rashedeen Mosque Park","Zaranik Protectorate","Al-Manshiya Square",
                "Al Koronfel Park","Al Marassi Beach","Mahmya Island","Saint Catherine's Monastery","Hurghada Beach","Al Zohour Club",
                "The Sunken City of Heracleion","Tiran Island","Al-Obour City Park","Al-Qaaed Park","Al-Rahmaniyah Park","Aswan Dam","Aswan High Dam",
                "Citadel of Qaitbay","Cleopatra's Bath","El Ein El Sokhna","El Sokhna Port","El-Tor Beach","Fanara Beach","Giza Plateau",
                "Hurgada Grand Aquarium","Kharga Oasis","Montaza Palace Gardens","New Marina, El Gouna","Port Said Lighthouse",
                "Qasr Al Sarab Desert Resort","Red Sea Monastery","Sharm El Sheikh Beach","Siwa Mountain","Sphinx Park","St. Anthony's Monastery",
                "St. Paul's Monastery","Taba Heights Beach","The Nile Corniche","Wadi Al-Hitan","Wadi Sannur Cave","Al-Omari Mosque Park",
                "Al-Quds Park","Aqua Park, Sharm El Sheikh","Cairo Tower","Dahab Beach","Fjord Bay","Karnak Temple","Luxor Temple",
                "Ras El-Soda Beach","Sharm El-Naga Beach",'ClueZ Egypt - Cairo', 'The Escape Room Egypt - Cairo', 'Brain Game Egypt - Cairo',
                'Escape Room Egypt - Alexandria', 'Great Escape Egypt - Cairo', 'Xcape Egypt - Cairo',"Pharaoh's Curse Escape Room - Cairo",
                'Key Quest Egypt - Cairo', 'Exit Games Egypt - Cairo','Escape It Egypt - Alexandria', 'Panic Room Egypt - Cairo', 
                'Questopia Egypt - Cairo','Paradox Egypt - Cairo', 'Mystery Rooms Egypt - Cairo', 'Breakout Egypt - Cairo',
                'Escape Artist Egypt - Cairo', 'Phobia Egypt - Cairo', 'Escapers Egypt - Cairo','Hysteria Egypt - Cairo', 'Code to Escape Egypt - Cairo',
                'Rooms Egypt - Alexandria','Xscapology Egypt - Cairo', 'Locked Room Egypt - Cairo', 'The Chamber Egypt - Cairo',
                'The Vault Egypt - Cairo', 'The Coven Egypt - Cairo', 'Insomnia Egypt - Cairo','Enigma Egypt - Cairo', 'Escapology Egypt - Cairo', 
                'Mind Maze Egypt - Cairo','The Great Escape Egypt - Alexandria', 'Adventure Rooms Egypt - Cairo', 'Get Out Egypt - Cairo',
                'Escape Room Egypt - Heliopolis', 'Escape Plan Egypt - Cairo', 'The Riddle Egypt - Cairo','Houdini Egypt - Cairo', 'Trapped Egypt - Cairo',
                'Enchanted Escape Egypt - Cairo','Escape In Egypt - Cairo', 'The Room Egypt - Cairo', 'The Box Egypt - Cairo','Mastermind Egypt - Cairo',
                'The Time Chamber Egypt - Cairo','Challenge Chambers Egypt - Cairo','Escape Hour Egypt - Cairo', 'Escape Egypt - Cairo', 'Breakout Egypt - Alexandria',
                'Panic Station Egypt - Cairo', 'Skoop Egypt - Cairo', 'Xroomz Egypt - Cairo','Escape Zone Egypt - Cairo', 'Amaze Egypt - Cairo',
                'The Escapers Egypt - Alexandria','Exit Egypt - Cairo', 'The Escape Room Egypt - El Gouna', 'The Secret Chambers Egypt - Cairo',
                'Locked Up Egypt - Cairo', 'A.S.E. Egypt - Cairo', 'Exit Plan Egypt - Cairo','Find Your Way Egypt - Cairo', 'The Key Egypt - Cairo',
                'Lock\'n\'Load Egypt - Cairo','Hour Escape Egypt - Cairo', 'The Room Egypt - Alexandria', 'Getaway Egypt - Cairo',
                '6th Dimension Egypt - Cairo', 'The Escape Egypt - Hurghada', 'Time Lapse Egypt - Cairo','Roomz Egypt - Cairo', 
                'Escape the Crate Egypt - Cairo', 'The Basement Egypt - Cairo','Fox in a Box Egypt - Cairo', 'The Escape Hunt Experience Egypt - Cairo',
                'The Halls Egypt - Cairo','Flee Egypt - Cairo', 'Project Escape Egypt - Cairo', 'The Room Egypt - Giza', 'Raqs Egypt - Cairo',
                'Escape Egypt - Alexandria', 'Breakout Egypt - Sharm El Sheikh', 'The Key Egypt - Alexandria','Escape House Egypt - Cairo', 
                'Riddle Room Egypt - Cairo', 'The Chamber of Secrets Egypt - Cairo','Escapology Egypt - Alexandria', 'Break Egypt - Cairo',
                'Room Escape Egypt - Cairo','Escape Key Egypt - Alexandria','Cairo Jazz Club - Cairo', 'The Tap East - New Cairo', 
                'The Tap West - Sheikh Zayed', 'The Tap Maadi - Cairo', 'Alchemy - Cairo', 'Zigzag - Cairo', 'ROOM Art Space & Cafe - Cairo',
                'Darb 1718 - Cairo', 'El Sawy Culturewheel - Cairo', 'El Genaina Theatre - Cairo', 'Bibliotheca Alexandrina - Alexandria', 'El Tanboura Hall - Cairo', 
                'The Greek Club - Alexandria', 'The Nile Maxim - Cairo', 'The Cairo Opera House - Cairo', 'El Dammah Theater - Cairo', 'Cairo Jazz Festival - Cairo',
                'Cairo International Convention Centre - Cairo', 'Rawabet Theater - Cairo', 'El Hanager Arts Centre - Cairo', 'El Sakia Theatre - Cairo', 
                'El Nahda Association for Arts and Culture - Alexandria', 'Beit El Sennari - Cairo', '100 Copies Music Space - Cairo', 'El Gomhoreya Theatre - Cairo', 
                'The Arab Music Institute - Cairo', 'Cairo Contemporary Dance Center - Cairo', 'The American University in Cairo - Cairo', 'The British Council - Cairo',
                'The French Institute - Cairo', 'The German Cultural Center - Cairo', 'The Italian Cultural Institute - Cairo', 'The Japan Foundation - Cairo',
                'The Swedish Institute - Alexandria', 'Darb 1718 Contemporary Art and Culture Center - Cairo', 'The Magnolia Hall - Cairo', 'Osiris - Cairo', 
                'Heliopolis Sporting Club - Cairo', 'The Nile Ritz-Carlton - Cairo', 'Cairo Marriott Hotel - Cairo', 'Sofitel Cairo Nile El Gezirah - Cairo', 
                'Four Seasons Hotel Cairo at Nile Plaza - Cairo', 'InterContinental Cairo Semiramis - Cairo', 'Mena House Hotel - Cairo', 'Ramses Hilton - Cairo',
                'Conrad Cairo - Cairo', 'Sheraton Cairo Hotel & Casino - Cairo', 'Hilton Cairo Zamalek Residences - Cairo', 'Kempinski Nile Hotel - Cairo',
                'The Westin Cairo Golf Resort & Spa - Cairo', 'Fairmont Nile City - Cairo', 'The St. Regis Cairo - Cairo', 'Le Méridien Pyramids Hotel & Spa - Cairo', 
                'Renaissance Cairo Mirage City Hotel - Cairo', 'The Nile Ritz-Carlton Spa - Cairo', 'The Waterway New Cairo - Cairo', 'Porto Cairo Mall - Cairo', 
                'Citystars - Cairo', 'Mall of Egypt - Cairo', 'Dandy Mega Mall - Cairo', 'Festival City Mall - Cairo', 'Sun City Mall - Cairo', 'Cairo Festival City - Cairo',
                'Downtown Katameya - New Cairo', 'Point 90 Mall - New Cairo', 'Galleria 40 - Cairo', 'The Platform - Cairo', 'The Tap Maadi Beach - Cairo',
                'Royal Maxim Palace Kempinski Cairo - Cairo', 'Pyramids Park Resort Cairo - Cairo', 'Swiss Inn Nile Hotel - Cairo', 'Cairo International Stadium - Cairo',
                'Borg El Arab Stadium - Alexandria', '30 June Stadium - Cairo', 'Al Ahly Sports Club - Cairo', 'El Gezira Sporting Club - Cairo',
                'Wadi Degla Sporting Club - Cairo', 'Shooting Club - Cairo', 'Royal Yacht Club - Alexandria','Dream Park', 'Magic Land', 'Aqua Park', 'Sindbad Aqua Park', 
                'Aladin Park', 'Tivoli Dome', 'Coney Island', 'Luna Park', 'Dinosaur Park', 'Cleopark', "Pharaoh's Island", 'Happy Land', 'Crazy Water Park', 'Jungle Aqua Park',
                'The Park Mall', 'Jolly Ville', 'Wonderland Park', 'Adventure Land', 'Blue Lagoon Aqua Park', 'Family Land', 'Dolphin Park', 'Fun Kingdom', 'Mystic Wadi', 
                'Magic Galaxy', 'Fun City', 'King Tut Aqua Park', 'Funtasia Water Park', 'Future Park', 'Ice Skating Rink', 'Magic World', 'Mirage Park', 'Mini Egypt Park',
                'The Grand Mall', 'The District Mall', 'The Greek Village', 'Happy Dolphin', 'Mega Mall', 'Miami Park', 'Nile City Towers', 'Nile Plaza Mall', 'Royal Mall',
                'Sky Mall', 'Sun City Mall', 'Tiba Outlet Mall', 'UpTown Mall', 'Wadi Adventure', 'Tanta Amusement Park', 'Dream Land', 'Sun Aqua Park', 'Sky Water Park',
                'Royal Water Park', 'Sky Fun Amusement Park', 'Pyramids Land', 'Luxor Land', 'Marina Land', 'Sun City Aqua Park', 'Giza Zoo', 'Maadi City Center',
                'Arabella Country Club', 'Genena City', 'Alexandria City Center', 'Porto Marina Resort and Spa', 'Al Kawther Water Park', 'Marassi', 'Rihana Resort', 
                'Titanic Aqua Park', 'Blue Bay', 'Pacha Sharm El Sheikh', 'Space Sharm El Sheikh', 'Soho Square Sharm El Sheikh', 'Aqua Blu Sharm El Sheikh', 
                'The Mall of Arabia', 'Almaza City Center', 'Mall of Egypt', 'First Mall', 'Golden Nile', 'Amazonia', 'Aqua Park Sokhna', 'Crazy Water Park Sokhna',
                'Green Valley', 'Sun Rise Aqua Park', 'Aqua Park City', 'Seoudi Supermarket', 'City Stars Mall', 'Festival City Mall', 'Downtown Mall', 'Sun City Hurghada',
                'Sphinx Aqua Park', 'Hadaba Aqua Park', 'Hurghada Grand Aquarium', 'Makadi Aqua Park', 'Jungle Aqua Park Hurghada', 'Titanic Beach Spa & Aqua Park', 
                'Alf Leila Wa Leila', 'Jungle Park', 'Sharm Cliff Park', 'Sharm Happy Land', 'Sharm Plaza', 'Aqua Park El-Quseir', 'Sun Wing Water World']
    place_type = ['indoor','outdoor']
    popularity = [random.uniform(10, 200) for i in range(num_samples)]
    rating_count = [100,200,500,1000, 2000, 3000, 4000, 5000,10000]
    avg_rating = [3.5, 4.0, 4.5, 5.0]
    budget = ['100', '250', '500', '1000']
    keywords = ['Food and drink', 'Outdoor activities', 'Sports', 'Music', 'Art and culture', 'Travel', 'Technology', 'Health and fitness','Photography','Reading','Volunteering','Fashion','DIY and crafts','History and politics','Science and nature','Pet lovers','Movies and TV','Gardening','Dancing','Cars','Parenting']
    
    # Generate unique place IDs for each place
    place_ids = list(range(1, num_samples+1))
    random.shuffle(place_ids)
    
    # Generate fake data for each sample
    data = []
    for i in range(num_samples):
        place_name = random.choice(places_names)
        selected_num_types = random.randint(1, len(place_type))
        selected_place_types = random.sample(place_type, selected_num_types)
        pop = popularity[i]
        rating_c = random.choice(rating_count)
        avg_r = random.choice(avg_rating)
        budg = random.choice(budget)
        kwords = random.sample(keywords, random.randint(1, len(keywords)))
        place_id = place_ids[i]
        data.append({'place_id': place_id, 'place_name': place_name, 'place_type': place_type, 'popularity': pop, 
                     'rating_count': rating_c, 'average_rating': avg_r, 'budget': budg, 'keywords': kwords})
    
    return data

# Generate data
data = generate_data(500)

# Write data to CSV file
with open('places_data.csv', 'w', newline='') as csvfile:
    fieldnames = ['place_id', 'place_name', 'place_type', 'popularity', 'rating_count', 'average_rating', 'budget', 'keywords']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for d in data:
        writer.writerow(d)

# Print the popularity field for each sample
for d in data:
    print("{:.6f}".format(d['popularity']))

print("Data saved to places_data.csv")
# Out:
# 139.619638
# 72.002679
# 155.555818
# 37.873488
# 12.426592
# 191.858874
# 68.461913
# 17.936623
# 38.526824
# 178.570165
# 89.728790
# 27.419295
# 103.627942
# 130.510431
# 15.028536
# 123.948599
# 120.351663
# 87.625764
# 103.009351
# 171.728431
# 23.325118
# 175.977841
# 126.502578
# 94.767063
# 108.803800
# 41.585446
# 46.180123
# 189.176677
# 199.483792
# 112.917582
# 102.216421
# 113.376801
# 87.821022
# 130.215859
# 85.065283
# 187.357336
# 169.670948
# 105.480440
# 124.456829
# 117.736524
# 84.932303
# 22.343770
# 33.164578
# 167.946192
# 97.322419
# 45.216029
# 18.358418
# 189.362519
# 143.482844
# 23.655225
# 137.971546
# 107.158025
# 132.613185
# 56.580256
# 114.211742
# 69.495233
# 69.928476
# 119.483626
# 92.249208
# 84.112014
# 72.646165
# 198.430584
# 176.533667
# 190.653924
# 54.275402
# 16.699699
# 159.481342
# 19.904389
# 156.851413
# 83.813618
# 133.481399
# 100.240304
# 101.069328
# 132.077378
# 31.995275
# 129.880193
# 39.563681
# 118.538939
# 106.601407
# ...

# %%
import csv
import random

# Generate fake data for places profile with unique place IDs
def generate_data(num_samples):
    # Define possible values for each field
    places_names = ['Costa Coffee - Citystars Mall, Cairo','Starbucks - Nile City Towers, Cairo','Cilantro - Maadi, Cairo',
                'Beano\'s Cafe - Maadi, Cairo','Coffee Beanery - Cairo Festival City Mall, Cairo','Caribou Coffee - Downtown Mall, Cairo',
                'The Coffee House - Maadi, Cairo','Trianon Cafe - Maadi, Cairo','Cinnabon Cafe - Citystars Mall, Cairo',
                'Second Cup - Mall of Egypt, Giza','Tim Hortons - Citystars Mall, Cairo','Coffee Lounge - Zamalek, Cairo',
                'Mugg & Bean - Zamalek, Cairo','Bon Appetit - Heliopolis, Cairo','Caffè Greco - Downtown, Cairo','Green & Beans - Maadi, Cairo',
                'La Poire Cafe - Nasr City, Cairo','Le Chantilly - Heliopolis, Cairo','Panorama Cafe - Downtown, Cairo',
                'Roasting House - New Cairo, Cairo','Yalla Bina - Mohandeseen, Cairo','Coffee Republic - Maadi, Cairo',
                'Cafe Supreme - Maadi, Cairo','Caffeine - Dokki, Cairo','T-Spot - Nasr City, Cairo','Felfela - Downtown, Cairo',
                'Java Java - Heliopolis, Cairo','Espresso Lab - Maadi, Cairo','Gourmandise - Zamalek, Cairo','The Kitchenette - New Cairo, Cairo',
                'The Corner - Mohandeseen, Cairo','The GrEEK Campus - Tahrir Square, Cairo','Caffè Nero - Cairo Festival City Mall, Cairo',
                'Dunkin\' Donuts - Multiple locations in Cairo','Paul Bakery & Cafe - Nile City Towers, Cairo','Cafe Supremo - New Cairo, Cairo',
                'Sufi - Zamalek, Cairo','Brioche Doree - Cairo Festival City Mall, Cairo','Caffe Greco - Heliopolis, Cairo','Cafe Tabasco - Maadi, Cairo',
                'Cafe Supreme - Zamalek, Cairo','Delice - Heliopolis, Cairo','Pascucci - Mall of Egypt, Giza','CinnZeo Bakery Cafe - Mall of Egypt, Giza',
                'El Beit - Zamalek, Cairo','Cafeina - New Cairo, Cairo','Tche Tche - Zamalek, Cairo','Divino Cafe & Restaurant - Maadi, Cairo',
                'Gardenia Cafe - Maadi, Cairo','Mince - New Cairo, Cairo','Filfila - Downtown, Cairo','Cafe Greco - Zamalek, Cairo',
                'Costa Coffee - Multiple locations in Cairo','Grand Cafe - Zamalek, Cairo','Tintawi - Maadi, Cairo','TBS - Heliopolis, Cairo',
                'Caffe Greco - Dokki, Cairo','The Bakery - Heliopolis, Cairo','La Maison Blanche - Heliopolis, Cairo','The Greek - Heliopolis, Cairo',
                'The GrEEK Campus - New Cairo, Cairo','Eish & Malh - Zamalek, Cairo',"Pub 28, Cairo","Le Deck, Alexandria","Cairo Jazz Club, Cairo",
                "The Tap Maadi, Cairo","Harry's Pub, Cairo","Cairo Capital Club, Cairo","Odeon Palace, Alexandria","The Tap West, Cairo",
                "The Lemon Tree & Co., Cairo","The Cellar, Cairo","The Tipsy Teapot, Cairo","L'Oasis, Cairo","Roof Bar, Cairo","The Tap East, Cairo",
                "The Smokery Beach, Alexandria","The Irish House, Cairo","Buddha-Bar, Cairo","Nozha Beach Club, Alexandria","Club 35, Cairo",
                "Sky Roof Bar & Lounge, Alexandria","Tipplers Bar, Cairo","Bus Stop, Cairo","Left Bank, Cairo","Pane Vino, Alexandria",
                "El Rowad, Cairo","Belal & Barzilai, Alexandria","Tamarai, Cairo","Taht El Saytara, Cairo","Rooftop Lounge & Bar, Alexandria",
                "La Bodega, Cairo","Little Buddha, Sharm El Sheikh","Grand Cafe, Cairo","La Bodega, Alexandria","The Backyard, Cairo",
                "The Terrace, Cairo","Soho Square, Sharm El Sheikh","Sabai Sabai, Cairo","Koshari Abou Tarek, Cairo","Fat Harry's, Cairo",
                "Loft21, Cairo","Indigo, Cairo","Sand Bar, Hurghada","Hard Rock Cafe, Cairo","Mojo Lounge & Grill, Cairo","Teatro, Cairo",
                "Buddha-Bar Beach, Sahel","Wunder Garten, Alexandria","The Bar, Cairo","Pegasus Lounge Bar, Alexandria","Terrace Cafe & Bar, Cairo",
                "The Royal Crown, Alexandria","I Bistro Bar, Cairo","The Lodge, Cairo","The Bistro, Cairo","The Tap Maadi Street 9, Cairo",
                "Deck 35, Alexandria","6IX Degrees, Cairo","Bamboo Beach, Hurghada","Les Amis, Cairo","Gouna Yacht Club, Hurghada",
                "O2 Lounge, Sharm El Sheikh","9 Lounge, Cairo","24K, Cairo","Enab Beirut, Cairo","Indigo Beach Club, Hurghada","Livingstone, Cairo",
                "Sky Bar, Hurghada","Cap d'Or, Alexandria","Tamara Lebanese Bistro, Cairo","Seagull Beach Bar, Hurghada""Harry's Pub, Alexandria",
                "Left Bank, Alexandria","Amici Bar & Grill, Cairo","Rio Nightclub, Sharm El Sheikh","The Lodge Bar, Alexandria",
                "The Tap Maadi Street 231, Cairo","La Plage, Alexandria","The Greek Campus, Cairo","El Horreya, Alexandria","Buddha-Bar, Sahel",
                "The Tap Downtown, Cairo","El Fishawy, Cairo","The Smokery, Cairo","Al-Azhar Park","Cairo International Park","Family Park in Maadi",
                "Al Horreya Park","Giza Zoo","Aswan Botanical Garden","Tivoli Dome","Gezira Club","Dream Park","Alexandria Zoo","Wadi Degla Protectorate",
                "Al Montazah Park","Fustat Park","Magic Land","Borg El Arab Stadium","City Stars Park","Ras Mohamed National Park","Al Andalus Park",
                "Ghibli Raceway","The Marina El Alamein","Tahrir Square","Siwa Oasis","Taziry Ecolodge Siwa","Al-Fayoum Oasis","Al-Galala Mountain",
                "Mersa Matrouh Beach","Al-Orman Garden","Oyoun Mousa","Cairo Festival City","Al Madina Park","Al-Masah Hotel and Spa","Pharos Island",
                "Zahran Park","Alex Park","Gabal Albaqar Mountain","Madinaty City","Al Rehab City","Al-Mashaya Reserve","Nubian Village",
                "The Great Sand Sea","El Fayoum Oasis","Al Khazan Park","Abu Simbel Temple","El Gouna","Serapium Forest","Al Mamoura Beach",
                "Ras El Bar","El Nabatat Island","Wadi Al-Natrun","Al Kholafaa Al Rashedeen Mosque Park","Zaranik Protectorate","Al-Manshiya Square",
                "Al Koronfel Park","Al Marassi Beach","Mahmya Island","Saint Catherine's Monastery","Hurghada Beach","Al Zohour Club",
                "The Sunken City of Heracleion","Tiran Island","Al-Obour City Park","Al-Qaaed Park","Al-Rahmaniyah Park","Aswan Dam","Aswan High Dam",
                "Citadel of Qaitbay","Cleopatra's Bath","El Ein El Sokhna","El Sokhna Port","El-Tor Beach","Fanara Beach","Giza Plateau",
                "Hurgada Grand Aquarium","Kharga Oasis","Montaza Palace Gardens","New Marina, El Gouna","Port Said Lighthouse",
                "Qasr Al Sarab Desert Resort","Red Sea Monastery","Sharm El Sheikh Beach","Siwa Mountain","Sphinx Park","St. Anthony's Monastery",
                "St. Paul's Monastery","Taba Heights Beach","The Nile Corniche","Wadi Al-Hitan","Wadi Sannur Cave","Al-Omari Mosque Park",
                "Al-Quds Park","Aqua Park, Sharm El Sheikh","Cairo Tower","Dahab Beach","Fjord Bay","Karnak Temple","Luxor Temple",
                "Ras El-Soda Beach","Sharm El-Naga Beach",'ClueZ Egypt - Cairo', 'The Escape Room Egypt - Cairo', 'Brain Game Egypt - Cairo',
                'Escape Room Egypt - Alexandria', 'Great Escape Egypt - Cairo', 'Xcape Egypt - Cairo',"Pharaoh's Curse Escape Room - Cairo",
                'Key Quest Egypt - Cairo', 'Exit Games Egypt - Cairo','Escape It Egypt - Alexandria', 'Panic Room Egypt - Cairo', 
                'Questopia Egypt - Cairo','Paradox Egypt - Cairo', 'Mystery Rooms Egypt - Cairo', 'Breakout Egypt - Cairo',
                'Escape Artist Egypt - Cairo', 'Phobia Egypt - Cairo', 'Escapers Egypt - Cairo','Hysteria Egypt - Cairo', 'Code to Escape Egypt - Cairo',
                'Rooms Egypt - Alexandria','Xscapology Egypt - Cairo', 'Locked Room Egypt - Cairo', 'The Chamber Egypt - Cairo',
                'The Vault Egypt - Cairo', 'The Coven Egypt - Cairo', 'Insomnia Egypt - Cairo','Enigma Egypt - Cairo', 'Escapology Egypt - Cairo', 
                'Mind Maze Egypt - Cairo','The Great Escape Egypt - Alexandria', 'Adventure Rooms Egypt - Cairo', 'Get Out Egypt - Cairo',
                'Escape Room Egypt - Heliopolis', 'Escape Plan Egypt - Cairo', 'The Riddle Egypt - Cairo','Houdini Egypt - Cairo', 'Trapped Egypt - Cairo',
                'Enchanted Escape Egypt - Cairo','Escape In Egypt - Cairo', 'The Room Egypt - Cairo', 'The Box Egypt - Cairo','Mastermind Egypt - Cairo',
                'The Time Chamber Egypt - Cairo','Challenge Chambers Egypt - Cairo','Escape Hour Egypt - Cairo', 'Escape Egypt - Cairo', 'Breakout Egypt - Alexandria',
                'Panic Station Egypt - Cairo', 'Skoop Egypt - Cairo', 'Xroomz Egypt - Cairo','Escape Zone Egypt - Cairo', 'Amaze Egypt - Cairo',
                'The Escapers Egypt - Alexandria','Exit Egypt - Cairo', 'The Escape Room Egypt - El Gouna', 'The Secret Chambers Egypt - Cairo',
                'Locked Up Egypt - Cairo', 'A.S.E. Egypt - Cairo', 'Exit Plan Egypt - Cairo','Find Your Way Egypt - Cairo', 'The Key Egypt - Cairo',
                'Lock\'n\'Load Egypt - Cairo','Hour Escape Egypt - Cairo', 'The Room Egypt - Alexandria', 'Getaway Egypt - Cairo',
                '6th Dimension Egypt - Cairo', 'The Escape Egypt - Hurghada', 'Time Lapse Egypt - Cairo','Roomz Egypt - Cairo', 
                'Escape the Crate Egypt - Cairo', 'The Basement Egypt - Cairo','Fox in a Box Egypt - Cairo', 'The Escape Hunt Experience Egypt - Cairo',
                'The Halls Egypt - Cairo','Flee Egypt - Cairo', 'Project Escape Egypt - Cairo', 'The Room Egypt - Giza', 'Raqs Egypt - Cairo',
                'Escape Egypt - Alexandria', 'Breakout Egypt - Sharm El Sheikh', 'The Key Egypt - Alexandria','Escape House Egypt - Cairo', 
                'Riddle Room Egypt - Cairo', 'The Chamber of Secrets Egypt - Cairo','Escapology Egypt - Alexandria', 'Break Egypt - Cairo',
                'Room Escape Egypt - Cairo','Escape Key Egypt - Alexandria','Cairo Jazz Club - Cairo', 'The Tap East - New Cairo', 
                'The Tap West - Sheikh Zayed', 'The Tap Maadi - Cairo', 'Alchemy - Cairo', 'Zigzag - Cairo', 'ROOM Art Space & Cafe - Cairo',
                'Darb 1718 - Cairo', 'El Sawy Culturewheel - Cairo', 'El Genaina Theatre - Cairo', 'Bibliotheca Alexandrina - Alexandria', 'El Tanboura Hall - Cairo', 
                'The Greek Club - Alexandria', 'The Nile Maxim - Cairo', 'The Cairo Opera House - Cairo', 'El Dammah Theater - Cairo', 'Cairo Jazz Festival - Cairo',
                'Cairo International Convention Centre - Cairo', 'Rawabet Theater - Cairo', 'El Hanager Arts Centre - Cairo', 'El Sakia Theatre - Cairo', 
                'El Nahda Association for Arts and Culture - Alexandria', 'Beit El Sennari - Cairo', '100 Copies Music Space - Cairo', 'El Gomhoreya Theatre - Cairo', 
                'The Arab Music Institute - Cairo', 'Cairo Contemporary Dance Center - Cairo', 'The American University in Cairo - Cairo', 'The British Council - Cairo',
                'The French Institute - Cairo', 'The German Cultural Center - Cairo', 'The Italian Cultural Institute - Cairo', 'The Japan Foundation - Cairo',
                'The Swedish Institute - Alexandria', 'Darb 1718 Contemporary Art and Culture Center - Cairo', 'The Magnolia Hall - Cairo', 'Osiris - Cairo', 
                'Heliopolis Sporting Club - Cairo', 'The Nile Ritz-Carlton - Cairo', 'Cairo Marriott Hotel - Cairo', 'Sofitel Cairo Nile El Gezirah - Cairo', 
                'Four Seasons Hotel Cairo at Nile Plaza - Cairo', 'InterContinental Cairo Semiramis - Cairo', 'Mena House Hotel - Cairo', 'Ramses Hilton - Cairo',
                'Conrad Cairo - Cairo', 'Sheraton Cairo Hotel & Casino - Cairo', 'Hilton Cairo Zamalek Residences - Cairo', 'Kempinski Nile Hotel - Cairo',
                'The Westin Cairo Golf Resort & Spa - Cairo', 'Fairmont Nile City - Cairo', 'The St. Regis Cairo - Cairo', 'Le Méridien Pyramids Hotel & Spa - Cairo', 
                'Renaissance Cairo Mirage City Hotel - Cairo', 'The Nile Ritz-Carlton Spa - Cairo', 'The Waterway New Cairo - Cairo', 'Porto Cairo Mall - Cairo', 
                'Citystars - Cairo', 'Mall of Egypt - Cairo', 'Dandy Mega Mall - Cairo', 'Festival City Mall - Cairo', 'Sun City Mall - Cairo', 'Cairo Festival City - Cairo',
                'Downtown Katameya - New Cairo', 'Point 90 Mall - New Cairo', 'Galleria 40 - Cairo', 'The Platform - Cairo', 'The Tap Maadi Beach - Cairo',
                'Royal Maxim Palace Kempinski Cairo - Cairo', 'Pyramids Park Resort Cairo - Cairo', 'Swiss Inn Nile Hotel - Cairo', 'Cairo International Stadium - Cairo',
                'Borg El Arab Stadium - Alexandria', '30 June Stadium - Cairo', 'Al Ahly Sports Club - Cairo', 'El Gezira Sporting Club - Cairo',
                'Wadi Degla Sporting Club - Cairo', 'Shooting Club - Cairo', 'Royal Yacht Club - Alexandria','Dream Park', 'Magic Land', 'Aqua Park', 'Sindbad Aqua Park', 
                'Aladin Park', 'Tivoli Dome', 'Coney Island', 'Luna Park', 'Dinosaur Park', 'Cleopark', "Pharaoh's Island", 'Happy Land', 'Crazy Water Park', 'Jungle Aqua Park',
                'The Park Mall', 'Jolly Ville', 'Wonderland Park', 'Adventure Land', 'Blue Lagoon Aqua Park', 'Family Land', 'Dolphin Park', 'Fun Kingdom', 'Mystic Wadi', 
                'Magic Galaxy', 'Fun City', 'King Tut Aqua Park', 'Funtasia Water Park', 'Future Park', 'Ice Skating Rink', 'Magic World', 'Mirage Park', 'Mini Egypt Park',
                'The Grand Mall', 'The District Mall', 'The Greek Village', 'Happy Dolphin', 'Mega Mall', 'Miami Park', 'Nile City Towers', 'Nile Plaza Mall', 'Royal Mall',
                'Sky Mall', 'Sun City Mall', 'Tiba Outlet Mall', 'UpTown Mall', 'Wadi Adventure', 'Tanta Amusement Park', 'Dream Land', 'Sun Aqua Park', 'Sky Water Park',
                'Royal Water Park', 'Sky Fun Amusement Park', 'Pyramids Land', 'Luxor Land', 'Marina Land', 'Sun City Aqua Park', 'Giza Zoo', 'Maadi City Center',
                'Arabella Country Club', 'Genena City', 'Alexandria City Center', 'Porto Marina Resort and Spa', 'Al Kawther Water Park', 'Marassi', 'Rihana Resort', 
                'Titanic Aqua Park', 'Blue Bay', 'Pacha Sharm El Sheikh', 'Space Sharm El Sheikh', 'Soho Square Sharm El Sheikh', 'Aqua Blu Sharm El Sheikh', 
                'The Mall of Arabia', 'Almaza City Center', 'Mall of Egypt', 'First Mall', 'Golden Nile', 'Amazonia', 'Aqua Park Sokhna', 'Crazy Water Park Sokhna',
                'Green Valley', 'Sun Rise Aqua Park', 'Aqua Park City', 'Seoudi Supermarket', 'City Stars Mall', 'Festival City Mall', 'Downtown Mall', 'Sun City Hurghada',
                'Sphinx Aqua Park', 'Hadaba Aqua Park', 'Hurghada Grand Aquarium', 'Makadi Aqua Park', 'Jungle Aqua Park Hurghada', 'Titanic Beach Spa & Aqua Park', 
                'Alf Leila Wa Leila', 'Jungle Park', 'Sharm Cliff Park', 'Sharm Happy Land', 'Sharm Plaza', 'Aqua Park El-Quseir', 'Sun Wing Water World']
    place_types = ['indoor', 'outdoor']
    popularity = [random.randint(100, 10000) for _ in range(num_samples)]
    rating_count = [100,200,500,1000, 2000, 3000, 4000, 5000,10000]
    avg_rating = [round(random.uniform(1.0, 5.0), 2) for _ in range(num_samples)]
    budget = [round(random.uniform(100, 3000), 100) for _ in range(num_samples)]
    keywords = ['Food and drink', 'Outdoor activities', 'Sports', 'Music', 'Art and culture', 'Travel', 'Technology', 'Health and fitness', 'Photography', 'Reading', 'Volunteering', 'Fashion', 'DIY and crafts', 'History and politics', 'Science and nature', 'Pet lovers', 'Movies and TV', 'Gardening', 'Dancing', 'Cars', 'Parenting']
    
    # Generate unique place IDs for each place
    place_ids = list(range(1, num_samples+1))
    random.shuffle(place_ids)
    
    # Generate fake data for each sample
    data = []
    for i in range(num_samples):
        place_name = random.choice(places_names)
        selected_num_types = random.randint(1, len(place_types))
        selected_place_types = random.sample(place_types, selected_num_types)
        pop = popularity[i]
        rating_c = random.choice(rating_count)
        avg_r = avg_rating[i]
        budg = random.choice(budget)
        kwords = random.sample(keywords, random.randint(1, len(keywords)))
        place_id = place_ids[i]
        data.append({'place_id': place_id, 'place_name': place_name, 'place_type': selected_place_types, 
                     'popularity': pop, 'rating_count': rating_c, 'average_rating': avg_r, 'budget': budg, 
                     'keywords': kwords})
    
    return data

# Generate data
data = generate_data(1000)

# Write data to CSV file
with open('places_data.csv', 'w', newline='') as csvfile:
    fieldnames = ['place_id', 'place_name', 'place_type', 'popularity', 'rating_count', 'average_rating', 'budget', 'keywords']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for d in data:
        writer.writerow(d)

# Print the popularity field for each sample
for d in data:
    print("{:.6f}".format(d['popularity']))

print("Data saved to places_data.csv")
# Out:
# 3690.000000
# 9221.000000
# 8629.000000
# 9253.000000
# 5284.000000
# 3643.000000
# 5708.000000
# 7802.000000
# 1145.000000
# 5542.000000
# 6938.000000
# 2512.000000
# 4510.000000
# 4646.000000
# 2699.000000
# 2280.000000
# 6260.000000
# 2137.000000
# 7513.000000
# 1723.000000
# 7135.000000
# 189.000000
# 2867.000000
# 6534.000000
# 1830.000000
# 8611.000000
# 1041.000000
# 7487.000000
# 8303.000000
# 9546.000000
# 8731.000000
# 9925.000000
# 2063.000000
# 1270.000000
# 5101.000000
# 2483.000000
# 9463.000000
# 8534.000000
# 8485.000000
# 1613.000000
# 5600.000000
# 6138.000000
# 233.000000
# 4080.000000
# 275.000000
# 2791.000000
# 120.000000
# 7653.000000
# 6987.000000
# 9844.000000
# 8946.000000
# 421.000000
# 8424.000000
# 4742.000000
# 9609.000000
# 1042.000000
# 6968.000000
# 3594.000000
# 4525.000000
# 9115.000000
# 324.000000
# 6853.000000
# 2823.000000
# 6536.000000
# 894.000000
# 7471.000000
# 1170.000000
# 5493.000000
# 8592.000000
# 6987.000000
# 7456.000000
# ...
